# %%
# DELIVERABLE 1

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import citipy
from citipy import citipy

# 3 Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
citipy
# Out:
# <module 'citipy.citipy' from 'C:\\Users\\Gina\\anaconda3\\envs\\PythonData\\lib\\site-packages\\citipy\\citipy.py'>

# %%
# 4 Create a list for holding the cities using citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# 5 Perform API call with the OpenWeatherMap
# Import the requests library.
import requests

# Import the Weather API key.
from config import weather_api_key


url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 6 Run an API request for each of the cities.

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list. Using enumerate() method.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | verkhnevilyuysk
# Processing Record 5 of Set 1 | saskylakh
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | nabire
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | grand-santi
# Processing Record 11 of Set 1 | mehamn
# Processing Record 12 of Set 1 | muswellbrook
# Processing Record 13 of Set 1 | lagoa
# Processing Record 14 of Set 1 | venancio aires
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | geraldton
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | maragogi
# Processing Record 19 of Set 1 | columbus
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | zverinogolovskoye
# Processing Record 23 of Set 1 | shannon
# Processing Record 24 of Set 1 | wanning
# Processing Record 25 of Set 1 | san rafael
# Processing Record 26 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 1 | angra
# City not found. Skipping...
# Processing Record 28 of Set 1 | lorengau
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | faya
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | carroll
# Processing Record 33 of Set 1 | vao
# Processing Record 34 of Set 1 | mogos
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | alice springs
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | auki
# Processing Record 39 of Set 1 | iqaluit
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | itoman
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | ladario
# Processing Record 44 of Set 1 | buala
# Processing Record 45 of Set 1 | araouane
# Processing Record 46 of Set 1 | abu samrah
# Processing Record 47 of Set 1 | davila
# Processing Record 48 of Set 1 | kodiak
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | luchegorsk
# Processing Record 2 of Set 2 | peniche
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | padang
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 8 of Set 2 | kashi
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | vrangel
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | gori
# Processing Record 17 of Set 2 | bone
# Processing Record 18 of Set 2 | stoyba
# City not found. Skipping...
# Processing Record 19 of Set 2 | olafsvik
# Processing Record 20 of Set 2 | henties bay
# Processing Record 21 of Set 2 | severo-kurilsk
# Processing Record 22 of Set 2 | ulladulla
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | labuhan
# Processing Record 28 of Set 2 | sept-iles
# Processing Record 29 of Set 2 | kamaishi
# Processing Record 30 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 31 of Set 2 | pontianak
# Processing Record 32 of Set 2 | angoche
# Processing Record 33 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 2 | bilibino
# Processing Record 35 of Set 2 | orlik
# Processing Record 36 of Set 2 | havoysund
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | broome
# Processing Record 39 of Set 2 | saint george
# Processing Record 40 of Set 2 | hualmay
# Processing Record 41 of Set 2 | bulgan
# Processing Record 42 of Set 2 | lompoc
# Processing Record 43 of Set 2 | puerto suarez
# Processing Record 44 of Set 2 | lata
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 2 | guerrero negro
# Processing Record 48 of Set 2 | prince rupert
# Processing Record 49 of Set 2 | san patricio
# Processing Record 50 of Set 2 | mataura
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | cabo san lucas
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | dikson
# Processing Record 5 of Set 3 | la ronge
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | menongue
# Processing Record 8 of Set 3 | liepaja
# Processing Record 9 of Set 3 | jumla
# Processing Record 10 of Set 3 | kindu
# Processing Record 11 of Set 3 | mangan
# Processing Record 12 of Set 3 | fairbanks
# Processing Record 13 of Set 3 | nishihara
# Processing Record 14 of Set 3 | cherskiy
# Processing Record 15 of Set 3 | progreso
# Processing Record 16 of Set 3 | manta
# Processing Record 17 of Set 3 | margate
# Processing Record 18 of Set 3 | natal
# Processing Record 19 of Set 3 | camacupa
# Processing Record 20 of Set 3 | mandalgovi
# Processing Record 21 of Set 3 | gizo
# Processing Record 22 of Set 3 | edgewater
# Processing Record 23 of Set 3 | necochea
# Processing Record 24 of Set 3 | dunedin
# Processing Record 25 of Set 3 | kattivakkam
# Processing Record 26 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 3 | nianzishan
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | beringovskiy
# Processing Record 30 of Set 3 | qasigiannguit
# Processing Record 31 of Set 3 | kouroussa
# Processing Record 32 of Set 3 | new norfolk
# Processing Record 33 of Set 3 | hobart
# Processing Record 34 of Set 3 | malumfashi
# Processing Record 35 of Set 3 | mayskiy
# Processing Record 36 of Set 3 | sao felix do xingu
# Processing Record 37 of Set 3 | houlton
# Processing Record 38 of Set 3 | khudumelapye
# Processing Record 39 of Set 3 | mareeba
# Processing Record 40 of Set 3 | tessalit
# Processing Record 41 of Set 3 | barrow
# Processing Record 42 of Set 3 | brockville
# Processing Record 43 of Set 3 | yellowknife
# Processing Record 44 of Set 3 | vila
# Processing Record 45 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 3 | kamiiso
# Processing Record 47 of Set 3 | clyde river
# Processing Record 48 of Set 3 | huilong
# Processing Record 49 of Set 3 | ponta do sol
# Processing Record 50 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 4 | cayenne
# Processing Record 2 of Set 4 | zonalnaya stantsiya
# Processing Record 3 of Set 4 | grand gaube
# Processing Record 4 of Set 4 | hilo
# Processing Record 5 of Set 4 | arraial do cabo
# Processing Record 6 of Set 4 | osa
# Processing Record 7 of Set 4 | port elizabeth
# Processing Record 8 of Set 4 | owando
# Processing Record 9 of Set 4 | carballo
# Processing Record 10 of Set 4 | vestmannaeyjar
# Processing Record 11 of Set 4 | tocopilla
# Processing Record 12 of Set 4 | korla
# Processing Record 13 of Set 4 | los llanos de aridane
# Processing Record 14 of Set 4 | carauari
# Processing Record 15 of Set 4 | oildale
# Processing Record 16 of Set 4 | kavieng
# Processing Record 17 of Set 4 | rodos
# Processing Record 18 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 4 | mayor pablo lagerenza
# Processing Record 20 of Set 4 | kousseri
# Processing Record 21 of Set 4 | monterey
# Processing Record 22 of Set 4 | comodoro rivadavia
# Processing Record 23 of Set 4 | umm lajj
# Processing Record 24 of Set 4 | katsuura
# Processing Record 25 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 4 | campo verde
# Processing Record 27 of Set 4 | chiriqui grande
# Processing Record 28 of Set 4 | hami
# Processing Record 29 of Set 4 | kungurtug
# Processing Record 30 of Set 4 | abu dhabi
# Processing Record 31 of Set 4 | provideniya
# Processing Record 32 of Set 4 | martapura
# Processing Record 33 of Set 4 | shatalovo
# Processing Record 34 of Set 4 | ahipara
# Processing Record 35 of Set 4 | rakkestad
# Processing Record 36 of Set 4 | vitoria da conquista
# Processing Record 37 of Set 4 | inhambane
# Processing Record 38 of Set 4 | yar-sale
# Processing Record 39 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 4 | sarlat-la-caneda
# Processing Record 41 of Set 4 | samarai
# Processing Record 42 of Set 4 | codrington
# Processing Record 43 of Set 4 | ixtapa
# Processing Record 44 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | saint-georges
# Processing Record 46 of Set 4 | pascagoula
# Processing Record 47 of Set 4 | te anau
# Processing Record 48 of Set 4 | butaritari
# Processing Record 49 of Set 4 | talcahuano
# Processing Record 50 of Set 4 | lavrentiya
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | avera
# Processing Record 3 of Set 5 | hirara
# Processing Record 4 of Set 5 | mantua
# Processing Record 5 of Set 5 | oussouye
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | narwana
# Processing Record 8 of Set 5 | east patchogue
# Processing Record 9 of Set 5 | cam ranh
# Processing Record 10 of Set 5 | tecoanapa
# Processing Record 11 of Set 5 | college
# Processing Record 12 of Set 5 | boffa
# Processing Record 13 of Set 5 | broken hill
# Processing Record 14 of Set 5 | luebo
# Processing Record 15 of Set 5 | san felipe
# Processing Record 16 of Set 5 | sao filipe
# Processing Record 17 of Set 5 | pisco
# Processing Record 18 of Set 5 | paamiut
# Processing Record 19 of Set 5 | yatou
# Processing Record 20 of Set 5 | vardo
# Processing Record 21 of Set 5 | chokurdakh
# Processing Record 22 of Set 5 | caravelas
# Processing Record 23 of Set 5 | talnakh
# Processing Record 24 of Set 5 | adrar
# Processing Record 25 of Set 5 | tuktoyaktuk
# Processing Record 26 of Set 5 | bengkulu
# Processing Record 27 of Set 5 | pacific grove
# Processing Record 28 of Set 5 | bella vista
# Processing Record 29 of Set 5 | karratha
# Processing Record 30 of Set 5 | ingham
# Processing Record 31 of Set 5 | besikduzu
# Processing Record 32 of Set 5 | jangaon
# Processing Record 33 of Set 5 | mackay
# Processing Record 34 of Set 5 | tiznit
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | nikolskoye
# Processing Record 37 of Set 5 | jerantut
# Processing Record 38 of Set 5 | bomet
# Processing Record 39 of Set 5 | georgetown
# Processing Record 40 of Set 5 | kruisfontein
# Processing Record 41 of Set 5 | muroto
# Processing Record 42 of Set 5 | neuquen
# Processing Record 43 of Set 5 | imbituba
# Processing Record 44 of Set 5 | rinconada
# Processing Record 45 of Set 5 | san quintin
# Processing Record 46 of Set 5 | salinopolis
# Processing Record 47 of Set 5 | gingoog
# Processing Record 48 of Set 5 | boyolangu
# Processing Record 49 of Set 5 | honiara
# Processing Record 50 of Set 5 | biak
# Processing Record 1 of Set 6 | nuuk
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | san policarpo
# Processing Record 4 of Set 6 | niono
# Processing Record 5 of Set 6 | chum phae
# Processing Record 6 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 7 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 6 | griffith
# Processing Record 9 of Set 6 | port hardy
# Processing Record 10 of Set 6 | baykit
# Processing Record 11 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 6 | yulara
# Processing Record 13 of Set 6 | nouadhibou
# Processing Record 14 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 6 | lyss
# Processing Record 16 of Set 6 | forestville
# Processing Record 17 of Set 6 | parana
# Processing Record 18 of Set 6 | odweyne
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | khelyulya
# Processing Record 21 of Set 6 | moranbah
# Processing Record 22 of Set 6 | dingle
# Processing Record 23 of Set 6 | sibay
# Processing Record 24 of Set 6 | santa catalina
# Processing Record 25 of Set 6 | leningradskiy
# Processing Record 26 of Set 6 | yerbogachen
# Processing Record 27 of Set 6 | havelock
# Processing Record 28 of Set 6 | kahului
# Processing Record 29 of Set 6 | namibe
# Processing Record 30 of Set 6 | airai
# Processing Record 31 of Set 6 | honningsvag
# Processing Record 32 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 6 | cheyur
# City not found. Skipping...
# Processing Record 34 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 35 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 6 | lamu
# Processing Record 37 of Set 6 | mao
# Processing Record 38 of Set 6 | zaozerne
# Processing Record 39 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 41 of Set 6 | council bluffs
# Processing Record 42 of Set 6 | sinnamary
# Processing Record 43 of Set 6 | kavaratti
# Processing Record 44 of Set 6 | chardara
# Processing Record 45 of Set 6 | twentynine palms
# Processing Record 46 of Set 6 | ambilobe
# Processing Record 47 of Set 6 | forio
# Processing Record 48 of Set 6 | kimbe
# Processing Record 49 of Set 6 | russkaya polyana
# Processing Record 50 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 1 of Set 7 | port moresby
# Processing Record 2 of Set 7 | kalmunai
# Processing Record 3 of Set 7 | aklavik
# Processing Record 4 of Set 7 | tromso
# Processing Record 5 of Set 7 | la asuncion
# Processing Record 6 of Set 7 | mumford
# Processing Record 7 of Set 7 | lac du bonnet
# Processing Record 8 of Set 7 | palamos
# Processing Record 9 of Set 7 | asfi
# Processing Record 10 of Set 7 | mahebourg
# Processing Record 11 of Set 7 | jarjis
# City not found. Skipping...
# Processing Record 12 of Set 7 | riviere-au-renard
# Processing Record 13 of Set 7 | teknaf
# Processing Record 14 of Set 7 | dalvik
# Processing Record 15 of Set 7 | nybro
# Processing Record 16 of Set 7 | north bend
# Processing Record 17 of Set 7 | torbay
# Processing Record 18 of Set 7 | bojnurd
# Processing Record 19 of Set 7 | myitkyina
# Processing Record 20 of Set 7 | hobyo
# Processing Record 21 of Set 7 | bethel
# Processing Record 22 of Set 7 | saint-augustin
# Processing Record 23 of Set 7 | san juan
# Processing Record 24 of Set 7 | cidreira
# Processing Record 25 of Set 7 | san luis rio colorado
# Processing Record 26 of Set 7 | pangnirtung
# Processing Record 27 of Set 7 | laguna
# Processing Record 28 of Set 7 | isangel
# Processing Record 29 of Set 7 | visnes
# Processing Record 30 of Set 7 | isla mujeres
# Processing Record 31 of Set 7 | holme
# Processing Record 32 of Set 7 | samarinda
# Processing Record 33 of Set 7 | coihaique
# Processing Record 34 of Set 7 | doda
# Processing Record 35 of Set 7 | jiaxing
# Processing Record 36 of Set 7 | gat
# Processing Record 37 of Set 7 | rocha
# Processing Record 38 of Set 7 | conde
# Processing Record 39 of Set 7 | eyl
# Processing Record 40 of Set 7 | tarakan
# Processing Record 41 of Set 7 | kaitangata
# Processing Record 42 of Set 7 | norman wells
# Processing Record 43 of Set 7 | sarangani
# Processing Record 44 of Set 7 | longyearbyen
# Processing Record 45 of Set 7 | khandyga
# Processing Record 46 of Set 7 | poum
# Processing Record 47 of Set 7 | cockburn town
# Processing Record 48 of Set 7 | utica
# Processing Record 49 of Set 7 | fortuna
# Processing Record 50 of Set 7 | marathon
# Processing Record 1 of Set 8 | kiama
# Processing Record 2 of Set 8 | upernavik
# Processing Record 3 of Set 8 | santa vitoria do palmar
# Processing Record 4 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 8 | kisanga
# Processing Record 6 of Set 8 | nicolas bravo
# Processing Record 7 of Set 8 | sinjai
# Processing Record 8 of Set 8 | lingao
# Processing Record 9 of Set 8 | zhangjiakou
# Processing Record 10 of Set 8 | hofn
# Processing Record 11 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 8 | deputatskiy
# Processing Record 13 of Set 8 | itarema
# Processing Record 14 of Set 8 | shimoda
# Processing Record 15 of Set 8 | aykhal
# Processing Record 16 of Set 8 | moose factory
# Processing Record 17 of Set 8 | kainan
# Processing Record 18 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 8 | cabra
# Processing Record 20 of Set 8 | charters towers
# Processing Record 21 of Set 8 | tual
# Processing Record 22 of Set 8 | garza garcia
# Processing Record 23 of Set 8 | zyryanka
# Processing Record 24 of Set 8 | xiaoyi
# Processing Record 25 of Set 8 | lagunas
# Processing Record 26 of Set 8 | whitianga
# Processing Record 27 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 28 of Set 8 | kutum
# Processing Record 29 of Set 8 | santo antonio do ica
# Processing Record 30 of Set 8 | chernenko
# Processing Record 31 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 8 | tempio pausania
# Processing Record 33 of Set 8 | alanya
# Processing Record 34 of Set 8 | fez
# Processing Record 35 of Set 8 | mikuni
# Processing Record 36 of Set 8 | triunfo
# Processing Record 37 of Set 8 | vila velha
# Processing Record 38 of Set 8 | le passage
# Processing Record 39 of Set 8 | louth
# Processing Record 40 of Set 8 | victoria
# Processing Record 41 of Set 8 | nome
# Processing Record 42 of Set 8 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 43 of Set 8 | arlit
# Processing Record 44 of Set 8 | kapoeta
# Processing Record 45 of Set 8 | aiani
# Processing Record 46 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 47 of Set 8 | scituate
# Processing Record 48 of Set 8 | saint-pierre
# Processing Record 49 of Set 8 | jiangkou
# Processing Record 50 of Set 8 | nguruka
# Processing Record 1 of Set 9 | hasaki
# Processing Record 2 of Set 9 | palmer
# Processing Record 3 of Set 9 | sorland
# Processing Record 4 of Set 9 | constitucion
# Processing Record 5 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 9 | gornyy
# Processing Record 7 of Set 9 | nizwa
# Processing Record 8 of Set 9 | varberg
# Processing Record 9 of Set 9 | portel
# Processing Record 10 of Set 9 | touros
# Processing Record 11 of Set 9 | nerchinskiy zavod
# Processing Record 12 of Set 9 | marsh harbour
# Processing Record 13 of Set 9 | solnechnyy
# Processing Record 14 of Set 9 | quatre cocos
# Processing Record 15 of Set 9 | riyadh
# Processing Record 16 of Set 9 | sechura
# Processing Record 17 of Set 9 | amarante
# Processing Record 18 of Set 9 | buin
# Processing Record 19 of Set 9 | basco
# Processing Record 20 of Set 9 | tongren
# Processing Record 21 of Set 9 | matara
# Processing Record 22 of Set 9 | yelizovo
# Processing Record 23 of Set 9 | zarautz
# Processing Record 24 of Set 9 | zhigansk
# Processing Record 25 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 26 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 9 | zheleznodorozhnyy
# Processing Record 28 of Set 9 | porto santo
# Processing Record 29 of Set 9 | hervey bay
# Processing Record 30 of Set 9 | chicama
# Processing Record 31 of Set 9 | mayo
# Processing Record 32 of Set 9 | aquiraz
# Processing Record 33 of Set 9 | itupiranga
# Processing Record 34 of Set 9 | temerloh
# Processing Record 35 of Set 9 | pevek
# Processing Record 36 of Set 9 | boysun
# Processing Record 37 of Set 9 | booue
# Processing Record 38 of Set 9 | tura
# Processing Record 39 of Set 9 | kautokeino
# Processing Record 40 of Set 9 | piste
# Processing Record 41 of Set 9 | archidona
# Processing Record 42 of Set 9 | alexandria
# Processing Record 43 of Set 9 | mount gambier
# Processing Record 44 of Set 9 | saldanha
# Processing Record 45 of Set 9 | linz
# Processing Record 46 of Set 9 | syumsi
# Processing Record 47 of Set 9 | savannah bight
# Processing Record 48 of Set 9 | minggang
# Processing Record 49 of Set 9 | kirakira
# Processing Record 50 of Set 9 | port hedland
# Processing Record 1 of Set 10 | saint-paul
# Processing Record 2 of Set 10 | waverley
# Processing Record 3 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 10 | kupang
# Processing Record 5 of Set 10 | ayna
# Processing Record 6 of Set 10 | carahue
# Processing Record 7 of Set 10 | meulaboh
# Processing Record 8 of Set 10 | dillon
# Processing Record 9 of Set 10 | chor
# Processing Record 10 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 10 | maldonado
# Processing Record 12 of Set 10 | khandbari
# Processing Record 13 of Set 10 | zhangye
# Processing Record 14 of Set 10 | muravlenko
# Processing Record 15 of Set 10 | moog
# Processing Record 16 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 10 | port shepstone
# Processing Record 18 of Set 10 | zlobin
# Processing Record 19 of Set 10 | namie
# Processing Record 20 of Set 10 | anuradhapura
# Processing Record 21 of Set 10 | alice town
# Processing Record 22 of Set 10 | chenghai
# Processing Record 23 of Set 10 | half moon bay
# Processing Record 24 of Set 10 | oistins
# Processing Record 25 of Set 10 | chumikan
# Processing Record 26 of Set 10 | nara
# Processing Record 27 of Set 10 | alekseyevka
# Processing Record 28 of Set 10 | husavik
# Processing Record 29 of Set 10 | yantarnyy
# Processing Record 30 of Set 10 | kurumkan
# Processing Record 31 of Set 10 | altay
# Processing Record 32 of Set 10 | togur
# Processing Record 33 of Set 10 | kalabo
# Processing Record 34 of Set 10 | ngunguru
# Processing Record 35 of Set 10 | santo amaro da imperatriz
# Processing Record 36 of Set 10 | joshimath
# Processing Record 37 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 38 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 10 | tumut
# Processing Record 40 of Set 10 | dossor
# Processing Record 41 of Set 10 | christchurch
# Processing Record 42 of Set 10 | cumpas
# Processing Record 43 of Set 10 | khash
# Processing Record 44 of Set 10 | lipin bor
# Processing Record 45 of Set 10 | puro
# Processing Record 46 of Set 10 | port blair
# Processing Record 47 of Set 10 | newport
# Processing Record 48 of Set 10 | fujin
# Processing Record 49 of Set 10 | raga
# Processing Record 50 of Set 10 | maracaju
# Processing Record 1 of Set 11 | viedma
# Processing Record 2 of Set 11 | saint anthony
# Processing Record 3 of Set 11 | cherlak
# Processing Record 4 of Set 11 | kununurra
# Processing Record 5 of Set 11 | sibut
# Processing Record 6 of Set 11 | miramar
# Processing Record 7 of Set 11 | micheweni
# Processing Record 8 of Set 11 | jasper
# Processing Record 9 of Set 11 | we
# City not found. Skipping...
# Processing Record 10 of Set 11 | jalu
# Processing Record 11 of Set 11 | senneterre
# Processing Record 12 of Set 11 | portland
# Processing Record 13 of Set 11 | narsaq
# Processing Record 14 of Set 11 | port macquarie
# Processing Record 15 of Set 11 | tuatapere
# Processing Record 16 of Set 11 | berdigestyakh
# Processing Record 17 of Set 11 | high level
# Processing Record 18 of Set 11 | nagapattinam
# Processing Record 19 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 11 | bogande
# Processing Record 21 of Set 11 | appleton
# Processing Record 22 of Set 11 | road town
# Processing Record 23 of Set 11 | kimamba
# Processing Record 24 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 25 of Set 11 | cabedelo
# Processing Record 26 of Set 11 | hoquiam
# Processing Record 27 of Set 11 | wadi musa
# Processing Record 28 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 29 of Set 11 | tigre
# Processing Record 30 of Set 11 | komsomolskiy
# Processing Record 31 of Set 11 | nemuro
# Processing Record 32 of Set 11 | chipinge
# Processing Record 33 of Set 11 | harbour breton
# Processing Record 34 of Set 11 | olinda
# Processing Record 35 of Set 11 | vostok
# Processing Record 36 of Set 11 | cheremisinovo
# Processing Record 37 of Set 11 | calvillo
# Processing Record 38 of Set 11 | yumen
# Processing Record 39 of Set 11 | awbari
# Processing Record 40 of Set 11 | sterling
# Processing Record 41 of Set 11 | havre-saint-pierre
# Processing Record 42 of Set 11 | san lorenzo
# Processing Record 43 of Set 11 | galesong
# Processing Record 44 of Set 11 | el alto
# Processing Record 45 of Set 11 | mirabad
# Processing Record 46 of Set 11 | ipixuna
# Processing Record 47 of Set 11 | galveston
# Processing Record 48 of Set 11 | dubbo
# Processing Record 49 of Set 11 | senanga
# Processing Record 50 of Set 11 | nanakuli
# Processing Record 1 of Set 12 | mana
# Processing Record 2 of Set 12 | yining
# Processing Record 3 of Set 12 | bubaque
# Processing Record 4 of Set 12 | emerald
# Processing Record 5 of Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 6 of Set 12 | kibala
# Processing Record 7 of Set 12 | klyuchi
# Processing Record 8 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 12 | huarmey
# Processing Record 10 of Set 12 | dauphin
# Processing Record 11 of Set 12 | verin
# Processing Record 12 of Set 12 | gogrial
# Processing Record 13 of Set 12 | kieta
# Processing Record 14 of Set 12 | hambantota
# Processing Record 15 of Set 12 | cascais
# Processing Record 16 of Set 12 | marsa matruh
# Processing Record 17 of Set 12 | tambopata
# Processing Record 18 of Set 12 | bagdarin
# Processing Record 19 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 20 of Set 12 | cape canaveral
# Processing Record 21 of Set 12 | ponta delgada
# Processing Record 22 of Set 12 | lemesos
# City not found. Skipping...
# Processing Record 23 of Set 12 | caceres
# Processing Record 24 of Set 12 | kerema
# Processing Record 25 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 26 of Set 12 | rio gallegos
# Processing Record 27 of Set 12 | meilu
# City not found. Skipping...
# Processing Record 28 of Set 12 | grindavik
# Processing Record 29 of Set 12 | thinadhoo
# Processing Record 30 of Set 12 | shimanovsk
# Processing Record 31 of Set 12 | skibotn
# Processing Record 32 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 12 | kourou
# Processing Record 34 of Set 12 | lazaro cardenas
# Processing Record 35 of Set 12 | makat
# Processing Record 36 of Set 12 | naze
# Processing Record 37 of Set 12 | ierapetra
# Processing Record 38 of Set 12 | mahajanga
# Processing Record 39 of Set 12 | union
# Processing Record 40 of Set 12 | manwath
# City not found. Skipping...
# Processing Record 41 of Set 12 | palana
# Processing Record 42 of Set 12 | esfarayen
# Processing Record 43 of Set 12 | udachnyy
# Processing Record 44 of Set 12 | brzeg dolny
# Processing Record 45 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 12 | malvern
# Processing Record 47 of Set 12 | calbuco
# Processing Record 48 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 49 of Set 12 | oriximina
# Processing Record 50 of Set 12 | kasongo-lunda
# Processing Record 1 of Set 13 | zhuanghe
# Processing Record 2 of Set 13 | vila franca do campo
# Processing Record 3 of Set 13 | kasama
# Processing Record 4 of Set 13 | blagoyevo
# Processing Record 5 of Set 13 | tukums
# Processing Record 6 of Set 13 | rosetta
# Processing Record 7 of Set 13 | erdenet
# Processing Record 8 of Set 13 | alofi
# Processing Record 9 of Set 13 | mount isa
# Processing Record 10 of Set 13 | yuzhno-kurilsk
# Processing Record 11 of Set 13 | russell
# Processing Record 12 of Set 13 | addi ugri
# City not found. Skipping...
# Processing Record 13 of Set 13 | rio grande
# Processing Record 14 of Set 13 | zlonice
# Processing Record 15 of Set 13 | xuanzhou
# Processing Record 16 of Set 13 | santa rosa
# Processing Record 17 of Set 13 | mbandaka
# Processing Record 18 of Set 13 | vanavara
# Processing Record 19 of Set 13 | elizabeth city
# Processing Record 20 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 21 of Set 13 | morro bay
# Processing Record 22 of Set 13 | kuusamo
# Processing Record 23 of Set 13 | peleduy
# Processing Record 24 of Set 13 | braganca
# Processing Record 25 of Set 13 | ariquemes
# Processing Record 26 of Set 13 | phek
# Processing Record 27 of Set 13 | khani
# Processing Record 28 of Set 13 | yekaterinoslavka
# Processing Record 29 of Set 13 | victoria point
# Processing Record 30 of Set 13 | killarney
# Processing Record 31 of Set 13 | port-gentil
# Processing Record 32 of Set 13 | port lincoln
# Processing Record 33 of Set 13 | buraydah
# Processing Record 34 of Set 13 | panaba
# Processing Record 35 of Set 13 | ferzikovo
# Processing Record 36 of Set 13 | olavarria
# Processing Record 37 of Set 13 | kurchum
# Processing Record 38 of Set 13 | anloga
# Processing Record 39 of Set 13 | helong
# Processing Record 40 of Set 13 | ketchikan
# Processing Record 41 of Set 13 | asekeyevo
# Processing Record 42 of Set 13 | kerewan
# Processing Record 43 of Set 13 | goderich
# Processing Record 44 of Set 13 | tucurui
# Processing Record 45 of Set 13 | yaan
# Processing Record 46 of Set 13 | qinhuangdao
# Processing Record 47 of Set 13 | lima
# Processing Record 48 of Set 13 | maniitsoq
# Processing Record 49 of Set 13 | rusape
# Processing Record 50 of Set 13 | taltal
# Processing Record 1 of Set 14 | rawson
# Processing Record 2 of Set 14 | ancud
# Processing Record 3 of Set 14 | asau
# Processing Record 4 of Set 14 | aripuana
# Processing Record 5 of Set 14 | springbok
# Processing Record 6 of Set 14 | harper
# Processing Record 7 of Set 14 | luderitz
# Processing Record 8 of Set 14 | morgan city
# Processing Record 9 of Set 14 | pemangkat
# Processing Record 10 of Set 14 | lubango
# Processing Record 11 of Set 14 | beyneu
# Processing Record 12 of Set 14 | kushima
# Processing Record 13 of Set 14 | mouscron
# Processing Record 14 of Set 14 | olindina
# Processing Record 15 of Set 14 | ojinaga
# Processing Record 16 of Set 14 | beloha
# Processing Record 17 of Set 14 | promyshlennaya
# Processing Record 18 of Set 14 | houma
# Processing Record 19 of Set 14 | makung
# City not found. Skipping...
# Processing Record 20 of Set 14 | rundu
# Processing Record 21 of Set 14 | chiradzulu
# Processing Record 22 of Set 14 | mazagao
# Processing Record 23 of Set 14 | ledyard
# Processing Record 24 of Set 14 | saumur
# Processing Record 25 of Set 14 | doha
# Processing Record 26 of Set 14 | homer
# Processing Record 27 of Set 14 | juli
# Processing Record 28 of Set 14 | ranong
# Processing Record 29 of Set 14 | lethem
# Processing Record 30 of Set 14 | ostrovnoy
# Processing Record 31 of Set 14 | port augusta
# Processing Record 32 of Set 14 | buchanan
# Processing Record 33 of Set 14 | anadyr
# Processing Record 34 of Set 14 | teya
# Processing Record 35 of Set 14 | sola
# Processing Record 36 of Set 14 | gondar
# Processing Record 37 of Set 14 | ossora
# Processing Record 38 of Set 14 | khasan
# Processing Record 39 of Set 14 | puerto escondido
# Processing Record 40 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 41 of Set 14 | quelimane
# Processing Record 42 of Set 14 | rio de janeiro
# Processing Record 43 of Set 14 | channel-port aux basques
# Processing Record 44 of Set 14 | letterkenny
# Processing Record 45 of Set 14 | san cristobal
# Processing Record 46 of Set 14 | ambon
# Processing Record 47 of Set 14 | lokosovo
# Processing Record 48 of Set 14 | sur
# Processing Record 49 of Set 14 | kloulklubed
# Processing Record 50 of Set 14 | sakiai
# Processing Record 1 of Set 15 | luangwa
# Processing Record 2 of Set 15 | afyonkarahisar
# Processing Record 3 of Set 15 | katangli
# Processing Record 4 of Set 15 | ludwigsfelde
# Processing Record 5 of Set 15 | pychas
# Processing Record 6 of Set 15 | pulandian
# Processing Record 7 of Set 15 | rorvik
# Processing Record 8 of Set 15 | katima mulilo
# Processing Record 9 of Set 15 | pleshanovo
# Processing Record 10 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 11 of Set 15 | ordu
# Processing Record 12 of Set 15 | minab
# Processing Record 13 of Set 15 | waipawa
# Processing Record 14 of Set 15 | ucluelet
# Processing Record 15 of Set 15 | santa cruz de tenerife
# Processing Record 16 of Set 15 | pangody
# Processing Record 17 of Set 15 | okhotsk
# Processing Record 18 of Set 15 | bilma
# Processing Record 19 of Set 15 | maningrida
# Processing Record 20 of Set 15 | monte santo de minas
# Processing Record 21 of Set 15 | sopelana
# Processing Record 22 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 23 of Set 15 | gundlupet
# Processing Record 24 of Set 15 | bandarbeyla
# Processing Record 25 of Set 15 | hamilton
# Processing Record 26 of Set 15 | talanga
# Processing Record 27 of Set 15 | nago
# Processing Record 28 of Set 15 | rio bananal
# Processing Record 29 of Set 15 | banfora
# Processing Record 30 of Set 15 | erenhot
# Processing Record 31 of Set 15 | sungaipenuh
# Processing Record 32 of Set 15 | jurm
# Processing Record 33 of Set 15 | sao joao da barra
# Processing Record 34 of Set 15 | ola
# Processing Record 35 of Set 15 | camacha
# Processing Record 36 of Set 15 | krasnoselkup
# Processing Record 37 of Set 15 | sitka
# Processing Record 38 of Set 15 | bang racham
# Processing Record 39 of Set 15 | wasilla
# Processing Record 40 of Set 15 | sal rei
# Processing Record 41 of Set 15 | goma
# Processing Record 42 of Set 15 | torbat-e jam
# Processing Record 43 of Set 15 | coahuayana
# Processing Record 44 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 15 | cassilandia
# Processing Record 46 of Set 15 | atlantic city
# Processing Record 47 of Set 15 | carsamba
# Processing Record 48 of Set 15 | grootfontein
# Processing Record 49 of Set 15 | saryozek
# Processing Record 50 of Set 15 | ostersund
# Processing Record 1 of Set 16 | vanimo
# Processing Record 2 of Set 16 | skibbereen
# Processing Record 3 of Set 16 | baruun-urt
# Processing Record 4 of Set 16 | clarksdale
# Processing Record 5 of Set 16 | hovd
# Processing Record 6 of Set 16 | tautira
# Processing Record 7 of Set 16 | abu kamal
# Processing Record 8 of Set 16 | plettenberg bay
# Processing Record 9 of Set 16 | lazarev
# Processing Record 10 of Set 16 | turbo
# Processing Record 11 of Set 16 | kuytun
# Processing Record 12 of Set 16 | bairiki
# Processing Record 13 of Set 16 | innisfail
# Processing Record 14 of Set 16 | bathsheba
# Processing Record 15 of Set 16 | egvekinot
# Processing Record 16 of Set 16 | chaykovskaya
# Processing Record 17 of Set 16 | hay river
# Processing Record 18 of Set 16 | novichikha
# Processing Record 19 of Set 16 | jiangyou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
# 7 Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Tiksi      RU  71.6872  128.8694    -12.42        91          19
# 1          Qaanaaq      GL  77.4840  -69.3632     -8.28        70          76
# 2    Mar Del Plata      AR -38.0023  -57.5575     64.87        72           0
# 3  Verkhnevilyuysk      RU  63.4453  120.3167    -15.18        98         100
# 4        Saskylakh      RU  71.9167  114.0833    -17.45        93          20
# 5          Ushuaia      AR -54.8000  -68.3000     38.86        75          40
# 6        Busselton      AU -33.6500  115.3333     81.05        46           0
# 7           Nabire      ID  -3.3667  135.4833     86.54        63          96
# 8            Vaini      TO -21.2000 -175.2000     86.16        74          40
# 9      Grand-Santi      GF   4.2500  -54.3833     71.96        99          47
#
#    Wind Speed Current Description
# 0       10.47          few clouds
# 1        6.76       broken clouds
# 2        1.99           clear sky
# 3        1.03     overcast clouds
# 4        3.02          few clouds
# 5       18.41    scattered clouds
# 6        9.48           clear sky
# 7        3.80     overcast clouds
# 8        8.05    scattered clouds
# 9        2.21       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
